# %%
import pandas as pd
df = pd.read_csv("../../raw_data/recipes_clean (1).csv")
ingredients = pd.read_csv("../../raw_data/ingredients.csv")
df
# Out:
#                                                name  \
# 0                                       Cheese Soup
# 1                                   Two Potato Soup
# 2                        Peanut-Topped Devil's Food
# 3                    White Chocolate Cashew Popcorn
# 4                             Joker Juice Smoothies
# ..                                              ...
# 295                    Cheese Crust Ground Beef Pie
# 296                                Asian Slaw Salad
# 297                              Jalapeno Egg Salad
# 298  Grandma Little's 50 Year Old Shortbread Recipe
# 299                              Tuna Celery Spread
#
#                                        ingredients_raw  \
# 0    ['1/2  cup   finely chopped celery', '2   cups...
# 1    ['1/2  lb    red potatoes, unpeeled and cut in...
# 2    ["1 (18 1/2  ounce) package   devil's food cak...
# 3    ['8 -10   cups   popped buttered popcorn', '1 ...
# 4    ['1 (10   ounce) bag   mixed berries', '1/2  c...
# ...

# %%
import ast

# Convertit le texte en vraie liste
df["type_dish_list"] = df["type_dish"].apply(ast.literal_eval)

# Compte les étiquettes
df["type_dish_list"].explode().value_counts()
# Out:
# type_dish_list
# vegetables               81
# salads                   30
# cookies-and-brownies     18
# beverages                16
# sandwiches               13
# breads                   12
# pasta                    11
# sweet                    10
# sauces                    8
# quick-breads              7
# salad-dressings           6
# cocktails                 6
# bisques-cream-soups       6
# cakes                     6
# bar-cookies               5
# candy                     4
# spaghetti                 3
# savory-sauces             3
# puddings-and-mousses      3
# cobblers-and-crisps       2
# clear-soups               2
# sweet-sauces              2
# pies-and-tarts            2
# brownies                  2
# coffee-cakes              2
# pork-loins                2
# pork-chops                2
# roast-beef                2
# barbecue                  2
# ravioli-tortellini        1
# jams-and-preserves        1
# scones                    1
# ...
